# %% [markdown]
# # This is a Liver Patient identification Data Set. The target is to identify whether the patient has an anomaly or abnormal functioning of the liver.

# %% [markdown]
# ## the import all library required

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## reading the dataset

# %% [markdown]
# #### here we are reading the data using the pandas library

# %%
new_data=pd.read_csv('D:\datamites projects task\liver pateint\PRCP-1007-LiverPatientPred\Data\Indian Liver Patient Dataset (ILPD).csv')

# %% [markdown]
# # EDA(Exploratory data analysis)

# %% [markdown]
# #### Exploratory data analysis  in which we seeing the shape of the data size of columns and size rows as shown below

# %%
new_data.shape
# Out:
# (582, 11)

# %%
new_data.columns=['Age','Gender','Total_Bilirubin','Direct_Bilirubin','Alkaline_Phosphotase','Alamine_Aminotransferase','Aspartate_Aminotransferase','Total_Protiens','Albumin','Albumin_and_Globulin_Ratio','target']

# %%
new_data
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     62   Male             10.9               5.5                   699
# 1     62   Male              7.3               4.1                   490
# 2     58   Male              1.0               0.4                   182
# 3     72   Male              3.9               2.0                   195
# 4     46   Male              1.8               0.7                   208
# ..   ...    ...              ...               ...                   ...
# 577   60   Male              0.5               0.1                   500
# 578   40   Male              0.6               0.1                    98
# 579   52   Male              0.8               0.2                   245
# 580   31   Male              1.3               0.5                   184
# 581   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          64                         100             7.5
# 1                          60                          68             7.0
# 2                          14                          20             6.8
# 3                          27                          59             7.3
# 4                          19                          14             7.6
# ..                        ...                         ...             ...
# 577                        20                          34             5.9
# 578                        35                          31             6.0
# 579                        48                          49             6.4
# 580                        29                          32             6.8
# 581                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  target
# 0        3.2                        0.74       1
# 1        3.3                        0.89       1
# 2        3.4                        1.00       1
# 3        2.4                        0.40       1
# 4        4.4                        1.30       1
# ..       ...                         ...     ...
# 577      1.6                        0.37       2
# 578      3.2                        1.10       1
# 579      3.2                        1.00       1
# 580      3.4                        1.00       1
# 581      4.4                        1.50       2
#
# [582 rows x 11 columns]

# %%
new_data
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     62   Male             10.9               5.5                   699
# 1     62   Male              7.3               4.1                   490
# 2     58   Male              1.0               0.4                   182
# 3     72   Male              3.9               2.0                   195
# 4     46   Male              1.8               0.7                   208
# ..   ...    ...              ...               ...                   ...
# 577   60   Male              0.5               0.1                   500
# 578   40   Male              0.6               0.1                    98
# 579   52   Male              0.8               0.2                   245
# 580   31   Male              1.3               0.5                   184
# 581   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          64                         100             7.5
# 1                          60                          68             7.0
# 2                          14                          20             6.8
# 3                          27                          59             7.3
# 4                          19                          14             7.6
# ..                        ...                         ...             ...
# 577                        20                          34             5.9
# 578                        35                          31             6.0
# 579                        48                          49             6.4
# 580                        29                          32             6.8
# 581                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  target
# 0        3.2                        0.74       1
# 1        3.3                        0.89       1
# 2        3.4                        1.00       1
# 3        2.4                        0.40       1
# 4        4.4                        1.30       1
# ..       ...                         ...     ...
# 577      1.6                        0.37       2
# 578      3.2                        1.10       1
# 579      3.2                        1.00       1
# 580      3.4                        1.00       1
# 581      4.4                        1.50       2
#
# [582 rows x 11 columns]

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 582 entries, 0 to 581
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         582 non-null    int64
#  1   Gender                      582 non-null    object
#  2   Total_Bilirubin             582 non-null    float64
#  3   Direct_Bilirubin            582 non-null    float64
#  4   Alkaline_Phosphotase        582 non-null    int64
#  5   Alamine_Aminotransferase    582 non-null    int64
#  6   Aspartate_Aminotransferase  582 non-null    int64
#  7   Total_Protiens              582 non-null    float64
#  8   Albumin                     582 non-null    float64
#  9   Albumin_and_Globulin_Ratio  578 non-null    float64
#  10  target                      582 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.1+ KB

# %%
new_data.describe(include='all')
# Out:
#                Age Gender  Total_Bilirubin  Direct_Bilirubin  \
# count   582.000000    582       582.000000        582.000000
# unique         NaN      2              NaN               NaN
# top            NaN   Male              NaN               NaN
# freq           NaN    441              NaN               NaN
# mean     44.711340    NaN         3.303265          1.488488
# std      16.181921    NaN         6.213926          2.810324
# min       4.000000    NaN         0.400000          0.100000
# 25%      33.000000    NaN         0.800000          0.200000
# 50%      45.000000    NaN         1.000000          0.300000
# 75%      57.750000    NaN         2.600000          1.300000
# max      90.000000    NaN        75.000000         19.700000
#
#         Alkaline_Phosphotase  Alamine_Aminotransferase  \
# count             582.000000                582.000000
# unique                   NaN                       NaN
# top                      NaN                       NaN
# freq                     NaN                       NaN
# mean              290.754296                 80.824742
# std               243.108929                182.757696
# min                63.000000                 10.000000
# 25%               175.250000                 23.000000
# 50%               208.000000                 35.000000
# 75%               298.000000                 60.750000
# max              2110.000000               2000.000000
#
#         Aspartate_Aminotransferase  Total_Protiens     Albumin  \
# count                   582.000000      582.000000  582.000000
# unique                         NaN             NaN         NaN
# top                            NaN             NaN         NaN
# freq                           NaN             NaN         NaN
# mean                    110.068729        6.482646    3.141581
# std                     289.141876        1.086306    0.796176
# min                      10.000000        2.700000    0.900000
# 25%                      25.000000        5.800000    2.600000
# 50%                      42.000000        6.600000    3.100000
# 75%                      87.000000        7.200000    3.800000
# max                    4929.000000        9.600000    5.500000
#
#         Albumin_and_Globulin_Ratio      target
# count                   578.000000  582.000000
# unique                         NaN         NaN
# top                            NaN         NaN
# freq                           NaN         NaN
# mean                      0.947145    1.286942
# std                       0.319863    0.452723
# min                       0.300000    1.000000
# 25%                       0.700000    1.000000
# 50%                       0.940000    1.000000
# 75%                       1.100000    2.000000
# max                       2.800000    2.000000

# %%
new_data.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# target                        0
# dtype: int64

# %%
# Let's start visualizing our attributes in the training dataset by printing some attributes vs the class they belong to.
print(new_data['Age'].value_counts())
print(40*'-')
print(new_data['Total_Bilirubin'].value_counts())
print(40*'-')
print(new_data['Direct_Bilirubin'].value_counts())
print(40*'-')
print(new_data['Alkaline_Phosphotase'].value_counts())
print(40*'-')
print(new_data['Alamine_Aminotransferase'].value_counts())
print(40*'-')
print(new_data['Aspartate_Aminotransferase'].value_counts())
print(40*'-')
print(new_data['Total_Protiens'].value_counts())
print(40*'-')
print(new_data['Albumin'].value_counts())
print(40*'-')
print(new_data['Albumin_and_Globulin_Ratio'].value_counts())
print(40*'-')
print(new_data['dataset'].value_counts())
# Out:
# 60    34
# 45    25
# 50    23
# 42    21
# 38    21
#       ..
# 10     1
# 8      1
# 84     1
# 6      1
# 90     1
# Name: Age, Length: 72, dtype: int64
# ----------------------------------------
# 0.8     91
# 0.7     76
# 0.9     57
# 0.6     46
# 1.0     28
#         ..
# 42.8     1
# 23.3     1
# 16.6     1
# 8.2      1
# 27.2     1
# Name: Total_Bilirubin, Length: 113, dtype: int64
# ----------------------------------------
# 0.2     194
# 0.1      62
# 0.3      51
# 0.8      22
# 0.4      21
#        ...
# 5.6       1
# 10.2      1
# 5.2       1
# 10.8      1
# 5.5       1
# Name: Direct_Bilirubin, Length: 80, dtype: int64
# ----------------------------------------
# 215     11
# 298     11
# 198     11
# 195     10
# 180     10
#         ..
# 352      1
# 349      1
# 348      1
# 342      1
# 1050     1
# Name: Alkaline_Phosphotase, Length: 263, dtype: int64
# ----------------------------------------
# 25      25
# 20      23
# 22      18
# 18      17
# 28      17
#         ..
# 71       1
# 75       1
# 76       1
# 78       1
# 2000     1
# Name: Alamine_Aminotransferase, Length: 152, dtype: int64
# ----------------------------------------
# 23     16
# 20     14
# 21     14
# 30     14
# 28     13
#        ..
# 161     1
# 156     1
# 155     1
# 150     1
# 10      1
# Name: Aspartate_Aminotransferase, Length: 177, dtype: int64
# ----------------------------------------
# 7.0    32
# 6.0    30
# 6.8    27
# 6.9    25
# 6.2    24
# 7.1    22
# 7.2    21
# 8.0    20
# 6.4    18
# 7.3    18
# 6.1    18
# 5.6    18
# 5.5    17
# 6.6    16
# 6.7    15
# 6.5    15
# 7.5    15
# 7.9    14
# 5.8    14
# 5.9    14
# 6.3    14
# 5.4    13
# 7.4    12
# 5.2    12
# 5.7    11
# 5.0    11
# 5.3    10
# 5.1    10
# 7.6     9
# 7.8     9
# 8.2     8
# 8.1     6
# 4.9     6
# 8.5     5
# 4.5     4
# 4.4     4
# 4.6     4
# 3.6     3
# 4.3     3
# 8.3     3
# 8.4     3
# 4.8     3
# 8.6     3
# 7.7     3
# 3.9     2
# 3.8     2
# 4.0     2
# 4.7     2
# 9.2     2
# 4.1     2
# 9.5     1
# 3.0     1
# 3.7     1
# 8.7     1
# 8.9     1
# 2.8     1
# 2.7     1
# 9.6     1
# Name: Total_Protiens, dtype: int64
# ----------------------------------------
# 3.0    45
# 4.0    37
# 2.9    29
# 3.1    28
# 3.2    26
# 3.9    25
# 2.7    24
# 2.5    24
# 3.5    23
# 3.4    21
# 2.0    21
# 2.6    21
# 3.7    21
# 3.3    20
# 2.8    18
# 3.6    18
# 2.4    17
# 4.1    16
# 3.8    15
# 4.3    14
# 2.1    14
# 2.3    12
# 4.2    12
# 1.8    12
# 2.2    12
# 1.6     8
# 4.4     8
# 1.9     7
# 4.5     6
# 4.9     4
# 4.6     4
# 1.5     3
# 4.7     3
# 1.4     3
# 1.7     3
# 5.5     2
# 4.8     2
# 0.9     2
# 1.0     1
# 5.0     1
# Name: Albumin, dtype: int64
# ----------------------------------------
# 1.00    106
# 0.80     65
# 0.90     58
# 0.70     53
# 1.10     46
#        ...
# 0.88      1
# 1.02      1
# 1.09      1
# 0.89      1
# 1.36      1
# Name: Albumin_and_Globulin_Ratio, Length: 69, dtype: int64
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dataset'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-9f606a19006f> in <module>
#      18 print(new_data['Albumin_and_Globulin_Ratio'].value_counts())
#      19 print(40*'-')
# ---> 20 print(new_data['dataset'].value_counts())
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'dataset'

# %%
def missing_values(new_data):
    total=new_data.isnull().sum().sort_values(ascending=False)
    percentage=(new_data.isnull().sum()/new_data.isnull().count()).sort_values(ascending=False)
    percentage_final=(round(percentage,2)*100)
    total_percentage=pd.concat(objs=[total,percentage_final],axis=1,keys=['total','%'])
    return total_percentage

# %%
missing_values(new_data)
# Out:
#                             total    %
# Albumin_and_Globulin_Ratio      4  1.0
# target                          0  0.0
# Albumin                         0  0.0
# Total_Protiens                  0  0.0
# Aspartate_Aminotransferase      0  0.0
# Alamine_Aminotransferase        0  0.0
# Alkaline_Phosphotase            0  0.0
# Direct_Bilirubin                0  0.0
# Total_Bilirubin                 0  0.0
# Gender                          0  0.0
# Age                             0  0.0

# %%
# then check to see that it has been successfull, where the sum of missig values should be 0
new_data['Albumin_and_Globulin_Ratio'].fillna(new_data['Albumin_and_Globulin_Ratio'].mean(), inplace = True)
new_data['Albumin_and_Globulin_Ratio'].isnull().sum()
# Out:
# 0

# %%
missing_values(new_data)
# Out:
#                             total    %
# target                          0  0.0
# Albumin_and_Globulin_Ratio      0  0.0
# Albumin                         0  0.0
# Total_Protiens                  0  0.0
# Aspartate_Aminotransferase      0  0.0
# Alamine_Aminotransferase        0  0.0
# Alkaline_Phosphotase            0  0.0
# Direct_Bilirubin                0  0.0
# Total_Bilirubin                 0  0.0
# Gender                          0  0.0
# Age                             0  0.0

# %%
sns.set()
sns.pairplot(new_data,hue='target',kind='reg')

# %% [markdown]
# We can see that some of the data is positivly corelated:
#
# Direct_Bilirubin and Total_Bilirubin are positivly corelated
# Aspartate_Aminotransferase and Alamine_Aminotransferase positivly corelated
# Total_Protiens and Albumin are also positivly corelated
# Albumin_and_Globulin_Ratio and Albumin positivly corelated
# Hence we can eliminate one of these variables

# %%
new_data.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_99b95296_7142_11eb_96c4_3c95098cfd5erow0_col0,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow1_col1,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow2_col2,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow3_col3,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow4_col4,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow5_col5,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow6_col6,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow7_col7,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow8_col8,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow9_col9{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow0_col1{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow0_col2{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow0_col3{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow0_col4,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow4_col9{
#             background-color:  #4f69d9;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow0_col5,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow7_col4{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow0_col6,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow0_col7,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow2_col9,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow3_col8,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow7_col0,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow7_col1,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow8_col3,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow9_col1,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow9_col2,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow9_col4,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow9_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow0_col8,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow7_col2,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow8_col1{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow0_col9{
#             background-color:  #5572df;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow1_col0{
#             background-color:  #82a6fb;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow1_col2{
#             background-color:  #d65244;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow1_col3,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow2_col5,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow4_col1{
#             background-color:  #b2ccfb;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow1_col4,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow5_col3,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow7_col9,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow8_col9{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow1_col5,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow9_col7{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow1_col6{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow1_col7,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow8_col2{
#             background-color:  #455cce;
#             color:  #f1f1f1;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow1_col8,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow1_col9{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow2_col0{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow2_col1{
#             background-color:  #d75445;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow2_col3,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow6_col8{
#             background-color:  #bad0f8;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow2_col4{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow2_col6{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow2_col7,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow2_col8{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow3_col0,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow3_col5{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow3_col1{
#             background-color:  #afcafc;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow3_col2,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow4_col2{
#             background-color:  #bbd1f8;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow3_col4{
#             background-color:  #8caffe;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow3_col6,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow5_col8{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow3_col7{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow3_col9{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow4_col0,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow5_col7{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow4_col3{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow4_col5,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow7_col6{
#             background-color:  #ea7b60;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow4_col6{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow4_col7{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow4_col8,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow9_col6{
#             background-color:  #779af7;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow5_col0,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow6_col2{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow5_col1{
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow5_col2{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow5_col4{
#             background-color:  #e97a5f;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow5_col6,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow8_col4{
#             background-color:  #6687ed;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow5_col9{
#             background-color:  #516ddb;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow6_col0{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow6_col1{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow6_col3{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3c95098cfd5erow6_col4,#T_99b95296_7142_11eb_96c4_3c95098cfd5erow9_col0{
#             background-color:  #5a78e4;
#             color:  #000000;
#         }#T_99b95296_7142_11eb_96c4_3

# %% [markdown]
# ###### We can see very high correlation between :
# ###### Direct_Bilirubin and Total_Bilirubin : 0.87
# ###### Aspartate_Aminotransferase and Alamine_Aminotransferase : 0.79
# ###### Total_Protiens and Albumin : 0.78
# ###### Albumin_and_Globulin_Ratio and Albumin : 0.69
# ###### Hence we can eliminate one of these variables

# %%
# we are endcoding gender columns which has the catagoricla object in integer 

new_data['Gender']=new_data['Gender'].map({'Male':1,'Female':0})

# %%
plt.figure(figsize=(10,5))
sns.heatmap(new_data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
data_Gender =(new_data[['Gender', 'target']].groupby(['Gender'], as_index=False).agg(np.sum))

# %%
data_Gender
# Out:
#    Gender  target
# 0       0     191
# 1       1     558

# %% [markdown]
# # Gender Analysis

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='Gender',y='target',data=data_Gender,ci=None)
plt.title('survival wrt Gender')
plt.ylim(0,700)
# Out:
# (0.0, 700.0)

# %% [markdown]
# # analysis of Albumin with respect to Gender and target

# %%
data_Albumin = round(new_data[['Gender', 'Albumin', 'target']].groupby(['Albumin', 'Gender'], as_index=False).agg(np.sum), 1)

# %%
data_Albumin
# Out:
#     Albumin  Gender  target
# 0       0.9       1       2
# 1       1.0       0       1
# 2       1.4       0       2
# 3       1.4       1       3
# 4       1.5       1       3
# ..      ...     ...     ...
# 69      4.9       0       4
# 70      4.9       1       1
# 71      5.0       1       2
# 72      5.5       0       1
# 73      5.5       1       1
#
# [74 rows x 3 columns]

# %%
plt.figure(figsize=(18,10))
sns.barplot(x='Albumin',y='target',hue='Gender',data=data_Albumin,ci=None)
plt.title('survival wrt Gender')
# Out:
# Text(0.5, 1.0, 'survival wrt Gender')

# %% [markdown]
# # data analysis of Total_protiens with Gender and target

# %%
data_Total_Protiens = round(new_data[['Gender', 'Total_Protiens', 'target']].groupby(['Total_Protiens', 'Gender'], as_index=False).agg(np.sum), 1)

# %%
data_Total_Protiens
# Out:
#      Total_Protiens  Gender  target
# 0               2.7       1       1
# 1               2.8       1       1
# 2               3.0       1       1
# 3               3.6       0       1
# 4               3.6       1       2
# ..              ...     ...     ...
# 97              8.9       0       1
# 98              9.2       0       2
# 99              9.2       1       1
# 100             9.5       1       1
# 101             9.6       1       1
#
# [102 rows x 3 columns]

# %%
plt.figure(figsize=(18,10))
sns.barplot(x='Total_Protiens',y='target',hue='Gender',data=data_Total_Protiens,ci=None)
plt.title('survival wrt Gender')
# Out:
# Text(0.5, 1.0, 'survival wrt Gender')

# %% [markdown]
# # data analysis of data_Albumin_and_Globulin_Ratio with Gender and target

# %%
data_Albumin_and_Globulin_Ratio = round(new_data[['Gender', 'Albumin_and_Globulin_Ratio', 'target']].groupby(['Albumin_and_Globulin_Ratio', 'Gender'], as_index=False).agg(np.sum), 1)

# %%
data_Albumin_and_Globulin_Ratio
# Out:
#     Albumin_and_Globulin_Ratio  Gender  target
# 0                          0.3       0       1
# 1                          0.3       1       3
# 2                          0.4       1       1
# 3                          0.4       1       2
# 4                          0.4       1       1
# ..                         ...     ...     ...
# 88                         1.8       0       4
# 89                         1.8       1       4
# 90                         1.9       1       2
# 91                         2.5       1       2
# 92                         2.8       1       1
#
# [93 rows x 3 columns]

# %%
plt.figure(figsize=(18,10))
sns.barplot(x='Albumin_and_Globulin_Ratio',y='target',hue='Gender',data=data_Albumin_and_Globulin_Ratio,ci=None)
plt.title('survival wrt Gender')
# Out:
# Text(0.5, 1.0, 'survival wrt Gender')

# %% [markdown]
# # data analysis of Age with Gender and target

# %%
data_Age = round(new_data[['Age', 'target']].groupby(['Age'], as_index=False).agg(np.sum), 3)

# %%
data_Age
# Out:
#     Age  target
# 0     4       4
# 1     6       2
# 2     7       3
# 3     8       1
# 4    10       1
# ..  ...     ...
# 67   75      14
# 68   78       1
# 69   84       2
# 70   85       2
# 71   90       1
#
# [72 rows x 2 columns]

# %%
plt.figure(figsize=(18,10))
sns.barplot(x='Age',y='target',data=data_Age,ci=None)
plt.title('survival wrt Age')
# Out:
# Text(0.5, 1.0, 'survival wrt Age')

# %%
# Figure configuration
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
# Visualize the effect of the dataset(with or without disease) based on both Albumin  and Gender.
ld = 'Liver Disease'
no_ld = 'No Liver Disease'
ax = sns.distplot(new_data[new_data['Gender'] == 0][new_data[new_data['Gender'] == 0]['target'] == 1]['Total_Bilirubin'], bins=18, label=ld, ax=axes[0], kde=False, color='blue')
ax = sns.distplot(new_data[new_data['Gender'] == 0][new_data[new_data['Gender'] == 0]['target'] == 2]['Total_Bilirubin'], 
                  bins=20, label=no_ld, ax=axes[0], kde=False, color='red')
ax.legend()
ax.set_title('Female')
ax.set_ylabel('Counts')

ax = sns.distplot(new_data[new_data['Gender'] == 1][new_data[new_data['Gender'] == 1]['target'] == 1]['Total_Bilirubin'], 
                  bins=18, label=ld, ax=axes[1], kde=False, color='blue')
ax = sns.distplot(new_data[new_data['Gender'] == 1][new_data[new_data['Gender'] == 1]['target'] == 2]['Total_Bilirubin'], 
                  bins=20, label=no_ld, ax=axes[1], kde=False, color='red')
ax.legend()
ax.set_title('Male')
# Out:
# Text(0.5, 1.0, 'Male')

# %%
# Figure configuration
fig,axes=plt.subplots(1, 2, figsize=(15, 5))
# Visualize the effect of the dataset(with or without disease) based on both Albumin  and Gender.
ld = 'Liver Disease'
no_ld = 'No Liver Disease'
ax = sns.distplot(new_data[new_data['Gender'] == 0][new_data[new_data['Gender'] == 0]['target'] == 1]['Direct_Bilirubin'], 
                  bins=18, label=ld, ax=axes[0], kde=False, color='blue')
ax = sns.distplot(new_data[new_data['Gender'] == 0][new_data[new_data['Gender'] == 0]['target'] == 2]['Direct_Bilirubin'], 
                  bins=20, label=no_ld, ax=axes[0], kde=False, color='red')
ax.legend()
ax.set_title('Female')
ax.set_ylabel('Counts')
ax = sns.distplot(new_data[new_data['Gender'] == 1][new_data[new_data['Gender'] == 1]['target'] == 1]['Direct_Bilirubin'], 
                  bins=18, label=ld, ax=axes[1], kde=False, color='blue')
ax = sns.distplot(new_data[new_data['Gender'] == 1][new_data[new_data['Gender'] == 1]['target'] == 2]['Direct_Bilirubin'], 
                  bins=20, label=no_ld, ax=axes[1], kde=False, color='red')
ax.legend()
ax.set_title('Male')
# Out:
# Text(0.5, 1.0, 'Male')

# %%
# Figure configuration
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
# Visualize the effect of the dataset(with or without disease) based on both Albumin  and Gender.
ld = 'Liver Disease'
no_ld = 'No Liver Disease'
ax = sns.distplot(new_data[new_data['Gender'] == 0][new_data[new_data['Gender'] == 0]['target'] == 1]['Alkaline_Phosphotase'], 
                  bins=18, label=ld, ax=axes[0], kde=False, color='blue')
ax = sns.distplot(new_data[new_data['Gender'] == 0][new_data[new_data['Gender'] == 0]['target'] == 2]['Alkaline_Phosphotase'], 
                  bins=20, label=no_ld, ax=axes[0], kde=False, color='red')
ax.legend()
ax.set_title('Female')
ax.set_ylabel('Counts')
ax = sns.distplot(new_data[new_data['Gender'] == 1][new_data[new_data['Gender'] == 1]['target'] == 1]['Alkaline_Phosphotase'], 
                  bins=18, label=ld, ax=axes[1], kde=False, color='blue')
ax = sns.distplot(new_data[new_data['Gender'] == 1][new_data[new_data['Gender'] == 1]['target'] == 2]['Alkaline_Phosphotase'], 
                  bins=20, label=no_ld, ax=axes[1], kde=False, color='red')
ax.legend()
ax.set_title('Male')
# Out:
# Text(0.5, 1.0, 'Male')

# %%
# Figure configuration
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
# Visualize the effect of the dataset(with or without disease) based on both Albumin  and Gender.
ld = 'Liver Disease'
no_ld = 'No Liver Disease'
ax = sns.distplot(new_data[new_data['Gender'] == 0][new_data[new_data['Gender'] == 0]['target'] == 1]['Alamine_Aminotransferase'], 
                  bins=18, label=ld, ax=axes[0], kde=False, color='blue')
ax = sns.distplot(new_data[new_data['Gender'] == 0][new_data[new_data['Gender'] == 0]['target'] == 2]['Alamine_Aminotransferase'], 
                  bins=20, label=no_ld, ax=axes[0], kde=False, color='red')
ax.legend()
ax.set_title('Female')
ax.set_ylabel('Counts')
ax = sns.distplot(new_data[new_data['Gender'] == 1][new_data[new_data['Gender'] == 1]['target'] == 1]['Alamine_Aminotransferase'], 
                  bins=18, label=ld, ax=axes[1], kde=False, color='blue')
ax = sns.distplot(new_data[new_data['Gender'] == 1][new_data[new_data['Gender'] == 1]['target'] == 2]['Alamine_Aminotransferase'], 
                  bins=20, label=no_ld, ax=axes[1], kde=False, color='red')
ax.legend()
ax.set_title('Male')
# Out:
# Text(0.5, 1.0, 'Male')

# %%
# Figure configuration
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
# Visualize the effect of the dataset(with or without disease) based on both Albumin  and Gender.
ld = 'Liver Disease'
no_ld = 'No Liver Disease'
ax = sns.distplot(new_data[new_data['Gender'] == 0][new_data[new_data['Gender'] == 0]['target'] == 1]['Aspartate_Aminotransferase'], 
                  bins=18, label=ld, ax=axes[0], kde=False, color='blue')
ax = sns.distplot(new_data[new_data['Gender'] == 0][new_data[new_data['Gender'] == 0]['target'] == 2]['Aspartate_Aminotransferase'], 
                  bins=20, label=no_ld, ax=axes[0], kde=False, color='red')
ax.legend()
ax.set_title('Female')
ax.set_ylabel('Counts')
ax = sns.distplot(new_data[new_data['Gender'] == 1][new_data[new_data['Gender'] == 1]['target'] == 1]['Aspartate_Aminotransferase'], 
                  bins=18, label=ld, ax=axes[1], kde=False, color='blue')
ax = sns.distplot(new_data[new_data['Gender'] == 1][new_data[new_data['Gender'] == 1]['target'] == 2]['Aspartate_Aminotransferase'], 
                  bins=20, label=no_ld, ax=axes[1], kde=False, color='red')
ax.legend()
ax.set_title('Male')
# Out:
# Text(0.5, 1.0, 'Male')

# %%
# Figure configuration
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
# Visualize the effect of the dataset(with or without disease) based on both Albumin  and Gender.
ld = 'Liver Disease'
no_ld = 'No Liver Disease'
ax = sns.distplot(new_data[new_data['Gender'] == 0][new_data[new_data['Gender'] == 0]['target'] == 1]['Albumin'], 
                  bins=18, label=ld, ax=axes[0], kde=False, color='blue')
ax = sns.distplot(new_data[new_data['Gender'] == 0][new_data[new_data['Gender'] == 0]['target'] == 2]['Albumin'], 
                  bins=20, label=no_ld, ax=axes[0], kde=False, color='red')
ax.legend()
ax.set_title('Female')
ax.set_ylabel('Counts')
ax = sns.distplot(new_data[new_data['Gender'] == 1][new_data[new_data['Gender'] == 1]['target'] == 1]['Albumin'], 
                  bins=18, label=ld, ax=axes[1], kde=False, color='blue')
ax = sns.distplot(new_data[new_data['Gender'] == 1][new_data[new_data['Gender'] == 1]['target'] == 2]['Albumin'], 
                  bins=20, label=no_ld, ax=axes[1], kde=False, color='red')
ax.legend()
ax.set_title('Male')
# Out:
# Text(0.5, 1.0, 'Male')

# %%
# Figure configuration
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
# Visualize the effect of the dataset(with or without disease) based on both Albumin and Globulin Ratio  and Gender.
ld = 'Liver Disease'
no_ld = 'No Liver Disease'
ax = sns.distplot(new_data[new_data['Gender'] == 0][new_data[new_data['Gender'] == 0]['target'] == 1]['Albumin_and_Globulin_Ratio'], 
                  bins=18, label=ld, ax=axes[0], kde=False, color='blue')
ax = sns.distplot(new_data[new_data['Gender'] == 0][new_data[new_data['Gender'] == 0]['target'] == 2]['Albumin_and_Globulin_Ratio'], 
                  bins=20, label=no_ld, ax=axes[0], kde=False, color='red')
ax.legend()
ax.set_title('Female')
ax.set_ylabel('Counts')
ax = sns.distplot(new_data[new_data['Gender'] == 1][new_data[new_data['Gender'] == 1]['target'] == 1]['Albumin_and_Globulin_Ratio'], 
                  bins=18, label=ld, ax=axes[1], kde=False, color='blue')
ax = sns.distplot(new_data[new_data['Gender'] == 1][new_data[new_data['Gender'] == 1]['target'] == 2]['Albumin_and_Globulin_Ratio'], 
                  bins=20, label=no_ld, ax=axes[1], kde=False, color='red')
ax.legend()
ax.set_title('Male')
# Out:
# Text(0.5, 1.0, 'Male')

# %% [markdown]
# # skewness check

# %%
from scipy.stats import skew
for i in new_data:
    print(skew(new_data[i]))
# Out:
# -0.026323717704502512
# -1.2030741729521697
# 4.890819568925024
# 3.201059045356354
# 3.751886848871077
# 6.527090900316633
# 10.511160201500676
# -0.2832929441976516
# -0.04252804313681592
# 0.9915821148155031
# 0.942040115214833

# %% [markdown]
# #  finding the skewd data

# %%
from sklearn.preprocessing import power_transform
def skewedness(data):
    skewed=[]
    for col in data:
        sk=skew(data[col])
        if(sk>1.9 or sk<=-1.9):
            skewed.append(col)
    return skewed
skewd_values=skewedness(new_data)
skewd_values
# Out:
# ['Total_Bilirubin',
#  'Direct_Bilirubin',
#  'Alkaline_Phosphotase',
#  'Alamine_Aminotransferase',
#  'Aspartate_Aminotransferase']

# %% [markdown]
#  # ploting the data

# %%
plt.figure(figsize=(12,10))
for index,cols in enumerate(new_data):
    plt.subplot(4,3,index+1)
    sns.distplot(new_data.loc[:,cols],kde=True,bins=30)
plt.tight_layout(pad=3)

# %%
inp_arry=new_data

# %% [markdown]
# # Applying the boxcox to the skewed data

# %%
from scipy import stats

Total_Bilirubin = stats.boxcox(inp_arry['Total_Bilirubin'])[0]
Direct_Bilirubin = stats.boxcox(inp_arry['Direct_Bilirubin'])[0]
Alkaline_Phosphotase = stats.boxcox(inp_arry['Alkaline_Phosphotase'])[0]
Alamine_Aminotransferase = stats.boxcox(inp_arry['Alamine_Aminotransferase'])[0]
Aspartate_Aminotransferase = stats.boxcox(inp_arry['Aspartate_Aminotransferase'])[0]

dataset = pd.DataFrame({'Total_Bilirubin': Total_Bilirubin, 'Direct_Bilirubin': Direct_Bilirubin,'Alkaline_Phosphotase':Alkaline_Phosphotase,
                       'Alamine_Aminotransferase':Alamine_Aminotransferase,'Aspartate_Aminotransferase':Aspartate_Aminotransferase})

dataset[['Age', 'Gender','Total_Protiens', 'Albumin','Albumin_and_Globulin_Ratio', 'target']] = inp_arry[['Age', 'Gender','Total_Protiens', 'Albumin','Albumin_and_Globulin_Ratio', 'target']]

new_df = pd.DataFrame()

new_df[['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
       'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
       'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
       'Albumin_and_Globulin_Ratio', 'target']] = dataset[['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
       'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
       'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
       'Albumin_and_Globulin_Ratio', 'target']]

new_df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     62       1         1.131923          1.283772              1.376652
# 1     62       1         1.050202          1.113430              1.373025
# 2     58       1         0.000000         -1.080320              1.356309
# 3     72       1         0.863438          0.615454              1.357897
# 4     46       1         0.478150         -0.379901              1.359314
# ..   ...     ...              ...               ...                   ...
# 577   60       1        -0.901695         -3.539647              1.373257
# 578   40       1        -0.618827         -3.539647              1.337898
# 579   52       1        -0.242301         -2.161511              1.362625
# 580   31       1         0.238819         -0.784486              1.356566
# 581   38       1         0.000000         -1.497462              1.360112
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                    1.718607                    1.959739             7.5
# 1                    1.710835                    1.905379             7.0
# 2                    1.445992                    1.655994             6.8
# 3                    1.590010                    1.882903             7.3
# 4                    1.519000                    1.553889             7.6
# ..                        ...                         ...             ...
# 577                  1.530180                    1.780878             5.9
# 578                  1.634818                    1.761199             6.0
# 579                  1.681889                    1.851277             6.4
# 580                  1.602949                    1.768054             6.8
# 581                  1.540545                    1.702262             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  target
# 0        3.2                        0.74       1
# 1        3.3                        0.89       1
# 2        3.4                        1.00       1
# 3        2.4                        0.40       1
# 4        4.4                        1.30       1
# ..       ...                         ...     ...
# 577      1.6                        0.37       2
# 578      3.2                        1.10       1
# 579      3.2                        1.00       1
# 580      3.4                        1.00       1
# 581      4.4                        1.50       2
#
# [582 rows x 11 columns]

# %%
df_data = new_df
df_data.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   62       1         1.131923          1.283772              1.376652
# 1   62       1         1.050202          1.113430              1.373025
# 2   58       1         0.000000         -1.080320              1.356309
# 3   72       1         0.863438          0.615454              1.357897
# 4   46       1         0.478150         -0.379901              1.359314
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                  1.718607                    1.959739             7.5
# 1                  1.710835                    1.905379             7.0
# 2                  1.445992                    1.655994             6.8
# 3                  1.590010                    1.882903             7.3
# 4                  1.519000                    1.553889             7.6
#
#    Albumin  Albumin_and_Globulin_Ratio  target
# 0      3.2                        0.74       1
# 1      3.3                        0.89       1
# 2      3.4                        1.00       1
# 3      2.4                        0.40       1
# 4      4.4                        1.30       1

# %%
x=df_data.iloc[:,:-1]

# %%
y=df_data.iloc[:,-1]

# %% [markdown]
# # feature scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(x,y)
# Out:
# StandardScaler()

# %%
from imblearn.over_sampling import SMOTE 
sm = SMOTE(random_state = 30) 
x_res, y_res = sm.fit_sample(x,y)

# %%
print(x_res.shape,y_res.shape)
# Out:
# (830, 10) (830,)

# %% [markdown]
# # spliting the data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_res,y_res,test_size=0.32,random_state=30)

# %% [markdown]
# # naive_bayes

# %%
from sklearn.naive_bayes import GaussianNB  
model = GaussianNB()  
model.fit(x_train,y_train)
y_predict=model.predict(x_test)
print(accuracy_score(y_test,y_predict))
print(f1_score(y_test,y_predict))
print(classification_report(y_test,y_predict))
print(roc_auc_score(y_test,y_predict))
print(confusion_matrix(y_test,y_predict))
print(50*'_')
y_predict1=model.predict(x_train)
print(accuracy_score(y_train,y_predict1))
print(f1_score(y_train,y_predict1))
print(classification_report(y_train,y_predict1))
print(roc_auc_score(y_train,y_predict1))
# Out:
# 0.706766917293233
# 0.6694915254237288
#               precision    recall  f1-score   support
#
#            1       0.80      0.58      0.67       137
#            2       0.65      0.84      0.74       129
#
#     accuracy                           0.71       266
#    macro avg       0.73      0.71      0.70       266
# weighted avg       0.73      0.71      0.70       266
#
# 0.7108017880382504
# [[ 79  58]
#  [ 20 109]]
# __________________________________________________
# 0.7322695035460993
# 0.6986027944111777
#               precision    recall  f1-score   support
#
#            1       0.78      0.63      0.70       278
#            2       0.70      0.83      0.76       286
#
#     accuracy                           0.73       564
#    macro avg       0.74      0.73      0.73       564
# weighted avg       0.74      0.73      0.73       564
#
# 0.730832117522765

# %%
from sklearn.model_selection import cross_val_score
score=cross_val_score(GaussianNB(),x_test,y_test)
score.mean()
# Out:
# 0.7067784765897974

# %% [markdown]
# # ploting roc_curve

# %%
from sklearn.metrics import plot_roc_curve,plot_precision_recall_curve
plot_roc_curve(model,x_test,y_test)
plt.plot([0,1],[0,1],c='k')

# %%
y_test.value_counts()
# Out:
# 1    137
# 2    129
# Name: target, dtype: int64

# %%
129/(137+129)
# Out:
# 0.4849624060150376

# %%
plot_precision_recall_curve(model,x_test,y_test)
plt.plot([0,1],[0.484,0.484],c='k')
